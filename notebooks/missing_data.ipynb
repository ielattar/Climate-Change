# %%
import missingno as msno
import numpy as np
# %matplotlib inline
import pandas as pd

# %%
all_data_filename = 'D:\\temp\\all.csv'
alldata_df = pd.read_csv(all_data_filename,engine='python').reset_index()
alldata_df.drop(alldata_df.columns[[1]], axis=1, inplace=True)
msno.matrix(alldata_df)
# Out:
# <AxesSubplot:>

# %%
alldata_df
# Out:
#        index  year  mean-temp(celsius)    stnid  total-prec(mm)  \
# 0          0  1913                 NaN  1012010             NaN
# 1          1  1914                 4.1  1012010             NaN
# 2          2  1915                 3.7  1012010             NaN
# 3          3  1916                 1.2  1012010             NaN
# 4          4  1917                 2.1  1012010             NaN
# ...      ...   ...                 ...      ...             ...
# 62096  62096  2015               -23.5  8504177             NaN
# 62097  62097  2016               -17.6  8504177             NaN
# 62098  62098  2017               -19.9  8504177             NaN
# 62099  62099  2018                 NaN  8504177             NaN
# 62100  62100  2019               -20.3  8504177             NaN
#
#        total-rain(mm)  total-snow(mm)  mean-sealevel-pressure(hPa)  \
# 0                 NaN             NaN                          NaN
# ...

# %%
msno.heatmap(alldata_df)
# Out:
# <AxesSubplot:>

# %%
 msno.bar(alldata_df)
# Out:
# <AxesSubplot:>

# %%
msno.dendrogram(alldata_df)
# Out:
# <AxesSubplot:>

# %%
null_pattern = (np.random.random(1000).reshape((50, 20)) > 0.5).astype(bool)
null_pattern = pd.DataFrame(null_pattern).replace({False: None})
msno.matrix(null_pattern.set_index(pd.period_range('1/1/2011', '2/1/2015', freq='M')) , freq='BQ')
# Out:
# <AxesSubplot:>
