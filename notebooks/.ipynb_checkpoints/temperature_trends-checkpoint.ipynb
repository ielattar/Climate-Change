# %%
import gdown
import glob
import folium
import pandas as pd
import os
import numpy as np
import datetime 
import seaborn as sns
from matplotlib import pyplot as plt
from pylab import *

# %% [markdown]
# **Load Mean Temperature Data For Stations.**

# %%
temp_filename = 'https://raw.githubusercontent.com/ielattar/Climate-Change/main/data/mean_temp.csv'
temp_df = pd.read_csv(temp_filename,engine='python').reset_index()
temp_df.drop(temp_df.columns[[1]], axis=1, inplace=True)
temp_df=temp_df.replace(-9999.9, np.nan)
temp_df=temp_df.dropna(axis=0, subset=['mean-temp(celsius)'])
temp_df.head(5)
# Out:
#    index  year  mean-temp(celsius)    stnid          Station name Prov  %Miss  \
# 1      1  1914                 4.1  1012010  COWICHAN_BAY_CHERRY_   BC    7.7
# 2      2  1915                 3.7  1012010  COWICHAN_BAY_CHERRY_   BC    7.7
# 3      3  1916                 1.2  1012010  COWICHAN_BAY_CHERRY_   BC    7.7
# 4      4  1917                 2.1  1012010  COWICHAN_BAY_CHERRY_   BC    7.7
# 5      5  1918                 3.7  1012010  COWICHAN_BAY_CHERRY_   BC    7.7
#
#    Lat(deg)  Long(deg)  Elev(m) Joined RCS
# 1      48.7     -123.5        0      n   n
# 2      48.7     -123.5        0      n   n
# 3      48.7     -123.5        0      n   n
# 4      48.7     -123.5        0      n   n
# 5      48.7     -123.5        0      n   n

# %% [markdown]
# **Find the Three Top Most Stations with highest record count by Province.**

# %%
temp_df_count=temp_df.groupby(['Prov','Station name']).size().sort_values(ascending=False).reset_index(name='count') 
sample_stations_df=temp_df_count.groupby('Prov').head(3)

# %% [markdown]
# **Filter The Mean Temperature Data Frame to only include the readings of the top stations.**

# %%
names_list = sample_stations_df['Station name'].values.tolist() 
name_list_str=','.join(names_list)
#print(name_list_str)
filtered_temp_df = temp_df[temp_df['Station name'].isin(names_list)]
filtered_temp_df.head(5)
# Out:
#      index  year  mean-temp(celsius)    stnid Station name Prov  %Miss  \
# 637    637  1899                 2.4  1018621     VICTORIA   BC    0.3
# 638    638  1900                 4.5  1018621     VICTORIA   BC    0.3
# 639    639  1901                 4.1  1018621     VICTORIA   BC    0.3
# 640    640  1902                 4.5  1018621     VICTORIA   BC    0.3
# 641    641  1903                 3.5  1018621     VICTORIA   BC    0.3
#
#      Lat(deg)  Long(deg)  Elev(m) Joined RCS
# 637      48.6     -123.4        2      y   n
# 638      48.6     -123.4        2      y   n
# 639      48.6     -123.4        2      y   n
# 640      48.6     -123.4        2      y   n
# 641      48.6     -123.4        2      y   n

# %% [markdown]
# **Create a 2D scatterplot with an overlaid regression line For temperature over time per Province**

# %%
chart=sns.lmplot(
            x='year',
            y='mean-temp(celsius)',
            data=filtered_temp_df,
            col='Prov',
            hue='Station name',
            legend_out=True,
            palette="tab20c",
            col_wrap=3,
            col_order=["YT","NWT","NU","BC","ALTA","SASK","MAN","ONT","QUE","NFLD","PEI"]
        )
plt.show()

# %% [markdown]
# **Ceate a 2D line plot showing temperature trends over time per Province**

# %%
chart=sns.relplot(
            x='year',
            y='mean-temp(celsius)',
            data=filtered_temp_df,
            col='Prov',
            hue='Station name',
            kind="line",
            palette="tab20c",
            col_wrap=3,
            col_order=["YT","NWT","NU","BC","ALTA","SASK","MAN","ONT","QUE","NFLD","PEI"]
        )
plt.show()

# %% [markdown]
# **Convert the year field to time and set it to be the index of the dataframe.**

# %%
#filtered_temp_df=filtered_temp_df.set_index('year')
#filtered_temp_df.index=pd.to_datetime(filtered_temp_df.index)
filtered_temp_df
# Out:
#        index  year  mean-temp(celsius)    stnid    Station name  Prov  %Miss  \
# 637      637  1899                 2.4  1018621        VICTORIA    BC    0.3
# 638      638  1900                 4.5  1018621        VICTORIA    BC    0.3
# 639      639  1901                 4.1  1018621        VICTORIA    BC    0.3
# 640      640  1902                 4.5  1018621        VICTORIA    BC    0.3
# 641      641  1903                 3.5  1018621        VICTORIA    BC    0.3
# ...      ...   ...                 ...      ...             ...   ...    ...
# 61968  61968  2015               -12.8  8502592  MARY_S_HARBOUR  NFLD    8.2
# 61969  61969  2016                -9.7  8502592  MARY_S_HARBOUR  NFLD    8.2
# 61970  61970  2017               -10.9  8502592  MARY_S_HARBOUR  NFLD    8.2
# 61971  61971  2018                -9.8  8502592  MARY_S_HARBOUR  NFLD    8.2
# 61972  61972  2019               -11.3  8502592  MARY_S_HARBOUR  NFLD    8.2
#
#        Lat(deg)  Long(deg)  Elev(m) Joined RCS
# 637        48.6     -123.4        2      y   n
# 638        48.6     -123.4        2      y   n
# 639        48.6     -123.4        2      y   n
# 640        48.6     -123.4        2      y   n
# 641        48.6     -123.4        2      y   n
# ...         ...        ...      ...    ...  ..
# 61968      52.3      -55.8        1      y   n
# 61969      52.3      -55.8        1      y   n
# 61970      52.3      -55.8        1      y   n
# 61971      52.3      -55.8        1      y   n
# 61972      52.3      -55.8        1      y   n
#
# [4819 rows x 12 columns]

# %%
provinces_list = filtered_temp_df['Prov'].unique().tolist() 

for aProvince in provinces_list:
    queryString="Prov == '"+ aProvince + "'"
    temp_prov_df=filtered_temp_df.query(queryString)
    temp_prov_df=temp_prov_df.set_index('year')
    temp_prov_df.index=pd.to_datetime(temp_prov_df.index)
    #temp_decade_df=temp_prov_df.resample('10AS').mean()
    print(temp_decade_df.head(50))
# Out:
#                    index  mean-temp(celsius)     %Miss   Lat(deg)  Long(deg)  \
# year
# 1970-01-01  61462.566845           -6.825668  6.252406  49.382353 -55.462567
#
#              Elev(m)
# year
# 1970-01-01  7.085561
#                    index  mean-temp(celsius)     %Miss   Lat(deg)  Long(deg)  \
# year
# 1970-01-01  61462.566845           -6.825668  6.252406  49.382353 -55.462567
#
#              Elev(m)
# year
# 1970-01-01  7.085561
#                    index  mean-temp(celsius)     %Miss   Lat(deg)  Long(deg)  \
# year
# 1970-01-01  61462.566845           -6.825668  6.252406  49.382353 -55.462567
#
#              Elev(m)
# year
# 1970-01-01  7.085561
#                    index  mean-temp(celsius)     %Miss   Lat(deg)  Long(deg)  \
# year
# 1970-01-01  61462.566845           -6.825668  6.252406  49.382353 -55.462567
#
#              Elev(m)
# year
# 1970-01-01  7.085561
#                    index  mean-temp(celsius)     %Miss   Lat(deg)  Long(deg)  \
# year
# 1970-01-01  61462.566845           -6.825668  6.252406  49.382353 -55.462567
#
#              Elev(m)
# year
# 1970-01-01  7.085561
#                    index  mean-temp(celsius)     %Miss   Lat(deg)  Long(deg)  \
# year
# 1970-01-01  61462.566845           -6.825668  6.252406  49.382353 -55.462567
#
#              Elev(m)
# year
# 1970-01-01  7.085561
#                    index  mean-temp(celsius)     %Miss   Lat(deg)  Long(deg)  \
# year
# 1970-01-01  61462.566845           -6.825668  6.252406  49.382353 -55.462567
#
#              Elev(m)
# year
# 1970-01-01  7.085561
#                    index  mean-temp(celsius)     %Miss   Lat(deg)  Long(deg)  \
# year
# 1970-01-01  61462.566845           -6.825668  6.252406  49.382353 -55.462567
#
#              Elev(m)
# year
# 1970-01-01  7.085561
#                    index  mean-temp(celsius)     %Miss   Lat(deg)  Long(deg)  \
# year
# 1970-01-01  61462.566845           -6.825668  6.252406  49.382353 -55.462567
#
#              Elev(m)
# year
# 1970-01-01  7.085561
#                    index  mean-temp(celsius)     %Miss   Lat(deg)  Long(deg)  \
# year
# 1970-01-01  61462.566845           -6.825668  6.252406  49.382353 -55.462567
#
#              Elev(m)
# year
# 1970-01-01  7.085561
#                    index  mean-temp(celsius)     %Miss   Lat(deg)  Long(deg)  \
# year
# 1970-01-01  61462.566845           -6.825668  6.252406  49.382353 -55.462567
#
#              Elev(m)
# year
# 1970-01-01  7.085561
#                    index  mean-temp(celsius)     %Miss   Lat(deg)  Long(deg)  \
# year
# 1970-01-01  61462.566845           -6.825668  6.252406  49.382353 -55.462567
#
#              Elev(m)
# year
# 1970-01-01  7.085561
#                    index  mean-temp(celsius)     %Miss   Lat(deg)  Long(deg)  \
# year
# 1970-01-01  61462.566845           -6.825668  6.252406  49.382353 -55.462567
#
#              Elev(m)
# year
# 1970-01-01  7.085561
